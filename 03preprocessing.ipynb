# %% [markdown]
# #

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Ejercicio 2: Modelo Vectorial y TF-IDF**
#
# **Objetivo de la práctica**
#
# * Comprender el modelo vectorial como base para representar documentos y consultas.
# * Calcular la matriz TF-IDF para el corpus data/01_corpus_turismo_500.txt

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/01-corpus-turismo-500/01_corpus_turismo_500.txt', delimiter='\t')
df

# %%
x = set(df)

# %%
ruta = '/kaggle/input/01-corpus-turismo-500/01_corpus_turismo_500.txt'
with open(ruta, 'r', encoding='utf-8') as f:
    text = f.read()

# %%
text

# %%
text.split('\n')

# %%
set(text.split(' ') )

# %%
import re
def preprocess(text):
    # Convierte el texto a minúsculas y extrae solo las palabras
    return re.findall(r'\b\w+\b', text.lower())

# %%
set(text.replace('\n', ' ').split())

# %%
set(text.replace('\n', ' ').replace('.','').split())

# %%
',' in text

# %%
set(text.replace('\n', ' ').replace('.', '').replace(',','').split())

# %%
set(text.lower().replace('\n', ' ').replace('.', '').replace(',','').split())

# %%
vocab = set(text.lower().replace('\n', ' ').replace('.', '').replace(',','').split())

# %%
len(vocab)

# %% [markdown]
# Primero hay que leer el corpus del archivo:

# %%
ruta = '/kaggle/input/01-corpus-turismo-500/01_corpus_turismo_500.txt'
with open(ruta, 'r', encoding='utf-8') as f:
    text = f.read()

# %% [markdown]
# Luego lo volvemos una lista y realizamos una limpieza:

# %%
vocab = list(set(text.lower().replace('\n', ' ').replace('.', '').replace(',','').split()))

# %% [markdown]
# hay que medir el tamaño:

# %%
len(vocab)

# %% [markdown]
# Ahora vamos a generar el corpus

# %%
corpus = text.split('\n')
corpus

# %%
doc = corpus[0]
doc.split()

# %%
doc = corpus[0]
doc

# %%
doc.split().count('es')

# %%
import numpy as np
def get_tf(doc):
    vec = []
    for word in vocab:
        cont = doc.lower().replace('.', '').replace(',', '').split().count(word)
        vec.append(cont)
    return np.array(vec)

# %%
x = get_tf(corpus[0])
x

# %%
vocab.index('rafting')

# %%
x[58]

# %%
corpus_vec = []
for doc in corpus:
    doc_vec = get_tf(doc)
    corpus_vec.append(doc_vec)

# %%
print(corpus_vec)
len(corpus_vec)

# %%
dft = np.sum(corpus_vec, axis = 0)
dft

# %%
min(dft)

# %%
np.argmin(dft)

# %%
vocab[75]

# %%
rankin = dft
len(rankin)
top118 = []
np.array(top118)

# %%
for _ in rankin:  # Por ejemplo, mover 5 elementos
    # Obtener el último elemento
    last = rankin[-1]
    
    # Eliminar el último elemento de 'a'
    rankin = np.delete(rankin, -1)
    
    # Agregar ese elemento a 'b'
    top118 = np.append(top118, last)

print("Array rankin:", rankin)
print("Array top118:", top118)

# %%
x = np.divide(118, dft)

# %%
np.log(x)

# %%
idf = np.log(np.divide(118, dft))

# %%
corpus_vec * idf

# %%
def get_idf(doc):
    log(N/df_t + 1)

# %%
for word in vocab:
